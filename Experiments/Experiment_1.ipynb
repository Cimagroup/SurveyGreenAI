# %% [markdown]
# In this notebook, we show how to use the reduction techniques over a simple 2D dataset. We plot the full dataset and the resulting reduced datasets, and we train a neural network with two hidden layers to test how do the reduced datasets generalize.

# %% [markdown]
# We start by importing all the required libraries

# %%
import math
import numpy as np
import time
import pandas as pd
from sklearn.preprocessing import normalize, MinMaxScaler
import random
import sys
import os
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_circles
os.chdir("../")
from main import data_reduction
os.chdir("Experiments/")
from exp_functions import experiment, plot_dataset
from sklearn.model_selection import train_test_split
os.chdir("Results/")
# Out:
# WARNING:tensorflow:From C:\Users\Javier\.conda\envs\survey\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# We describe a synthetic dataset

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2,
                           n_redundant=0, n_clusters_per_class=1, flip_y=0, random_state=4)
plot_dataset(X[y==0],X[y==1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=2024)

# %% [markdown]
# We set the arguments for the reduction

# %% [markdown]
# For each reduction method, the experiment follows the following steps:
#
# 1. Reduce the training dataset with that method.
# 2. Save the time needed to reduce the dataset.
# 3. Plots the full and reduced dataset.
# 4. Train the neural network over the reduced dataset.
# 5. Save the time needed to train the network.
# 6. Save the main performance metrics evaluated over the test set (accuracy, sensitivity, specificity and F1-score)
# 7. Repeat the steps 1-6 a total of n_iter times.
# 8. Save the mean and variance of each measure in an excel file called "metrics.xlsx".

# %% [markdown]
# The experiment depends on a set of parameter, that can be changed in the "exp_functions.py" file. For example, you can set how many reductions are done for each method by changing the n_iter argument, or you can decide the size of the reduced dataset by changing the perc (percentage) parameter.

# %%
experiment(X_train, y_train, X_test, y_test)
# Out:
# None
# Iteration  1 / 10
# WARNING:tensorflow:From C:\Users\Javier\.conda\envs\survey\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Javier\.conda\envs\survey\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Javier\.conda\envs\survey\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 10/10 [==============================] - 0s 1ms/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 0s/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 588us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 0s/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 0s/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 0s/step
# SRS
# Iteration  1 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 0s/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 981us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 762us/step
# CLC
# Iteration  1 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 1ms/step
# Iteration  2 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 2ms/step
# Iteration  3 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 2ms/step
# Iteration  4 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 2ms/step
# Iteration  5 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 1ms/step
# Iteration  6 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 2ms/step
# Iteration  7 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 0s/step
# Iteration  8 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 986us/step
# Iteration  9 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 798us/step
# Iteration  10 / 10
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Javier\.conda\envs\survey\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# 10/10 [==============================] - 0s 1ms/step
# MMS
# Iteration  1 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 2ms/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 546us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 845us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 935us/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 994us/step
# DES
# Iteration  1 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 854us/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 895us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 994us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 961us/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 879us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 887us/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 887us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 986us/step
# DOM
# Iteration  1 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 999us/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 780us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 852us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 752us/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 895us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 879us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 1ms/step
# PHL
# Iteration  1 / 10
# 10/10 [==============================] - 0s 886us/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 877us/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 785us/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 996us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 788us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 990us/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 885us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 1ms/step
# NRMD
# Iteration  1 / 10
# 10/10 [==============================] - 0s 883us/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 893us/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 916us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 883us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 777us/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 778us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 990us/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 889us/step
# PSA
# Iteration  1 / 10
# 10/10 [==============================] - 0s 940us/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 885us/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 800us/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 892us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 1ms/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 773us/step
# PRD
# Iteration  1 / 10
# 10/10 [==============================] - 0s 778us/step
# Iteration  2 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  3 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  4 / 10
# 10/10 [==============================] - 0s 778us/step
# Iteration  5 / 10
# 10/10 [==============================] - 0s 889us/step
# Iteration  6 / 10
# 10/10 [==============================] - 0s 778us/step
# Iteration  7 / 10
# 10/10 [==============================] - 0s 918us/step
# Iteration  8 / 10
# 10/10 [==============================] - 0s 778us/step
# Iteration  9 / 10
# 10/10 [==============================] - 0s 881us/step
# Iteration  10 / 10
# 10/10 [==============================] - 0s 840us/step

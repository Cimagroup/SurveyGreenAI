# %%
import numpy as np
import random 
import maxmin as mm
from matplotlib import pyplot as plt

# %% [markdown]
# data = np.array([[3.24314637, 2.84628719],
#  [4.6077903,  6.85928955],
#  [3.38225143, 5.52513369],
#  [8.47697793, 8.62220749],
#  [6.0487928,  9.36634767],
#  [3.04296503, 0.98335901],
#  [2.30451688, 4.53497644],
#  [1.11877387, 2.26047768],
#  [4.12596931, 8.53434279],
#  [6.24652727, 7.44176081]])
# n=5

# %%
random.seed(10)
x = np.random.uniform(0, 10, size=100)
y = np.random.uniform(0, 10, size=100)
data = np.column_stack((x, y))
n=15

# %%
plt.scatter(data[:, 0], data[:, 1])
for i in range(len(data)):
    plt.text(data[i,0],data[i,1],i)
plt.show()

# %%
random.seed(10)

# %%
picks = mm.maxmin_selector(data,n,1)
print(picks)
# Out:
# [ 8 18 25 37 43 54 59 61 70 72 73 78 79 92 95]

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.scatter(data[picks, 0], data[picks, 1], color = 'red')
for i in range(len(data)):
    plt.text(data[i,0],data[i,1],i)
plt.show()
